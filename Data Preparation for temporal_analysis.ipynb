# %% [markdown]
# # Data Preparation for Temporal PM Analysis
#
# This notebook prepares PM time-series data for analyzing
# pollution trends over time.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
air_quality = pd.read_csv("/content/drive/MyDrive/air_quality/Outputs/raw_air_quality_combined.csv",sep=';', low_memory=False)
air_quality.head()
# Out:
#    sensor_id sensor_type  location    lat     lon  \
# 0         40      SDS011         7 -1.298  36.791
# 1         40      SDS011         7 -1.298  36.791
# 2         40      SDS011         7 -1.298  36.791
# 3         40      SDS011         7 -1.298  36.791
# 4         43      SDS011        20 -1.253  36.854
#
#                           timestamp   value_type  value
# 0  2018-04-01T00:02:07.071983+00:00     humidity  65.80
# 1  2018-04-01T00:02:07.071983+00:00  temperature  21.10
# 2  2018-04-01T00:02:07.111462+00:00           P2   4.40
# 3  2018-04-01T00:02:07.111462+00:00           P1   7.80
# 4  2018-04-01T00:03:56.860816+00:00     humidity  76.30

# %% [markdown]
# ## Filtering and Cleaning PM Time-Series Data

# %%
pm_df = air_quality[air_quality["value_type"] == "P2"]
pm_df = pm_df.dropna(subset=["timestamp", "value"])
pm_df["timestamp"] = pd.to_datetime(pm_df["timestamp"], format='ISO8601')

# %% [markdown]
# ## Saving Clean Temporal Dataset

# %%
pm_df.to_csv("/content/drive/MyDrive/air_quality/Outputs/clean_temporal_pm.csv", index=False)
